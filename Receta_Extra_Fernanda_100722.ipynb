# %% [markdown]
# # Mentoria: Monitoreo de Espacios Verdes
#
# __DIPLODATOS 2022 - FAMAF UNC__
#
# _Felix Rojo Lapalma_
#
# ## Exploración y Curación de Datos
#
# En esta etapa ya hemos avanzado en (basados en el [TP-Analisis-Visualizacion](https://github.com/felixlapalma/monitoreo-espacios-verdes-diplo202X/blob/main/notebooks-tp/Analisis-y-Visualizacion-MEV-TP.ipynb)):
#
# - análisis y exploración del conjunto de datos (aunque sea superficialmente)
# - set representativo: Es decir, aprendimos que podemos llegar a trabajar con un set mas reducido (de las caracteristicas - columnas del dataframe) e igualmente vamos a estar representando gran parte del conjunto.
# - inputacion de valores:
#     - tenemos formas de inputar valores en rangos temporales que no tenemos (para una cierta zona) utilizando otros rangos temporales (aqui aprovechamos fuertemente la estacionalidad de lo que estamos monitoreando)
#     - que un outlier en un rango temporal puede ser un valor nominal en otro rango temporal.
#
# - etc
#
# En lo que sigue vamos a aplicar mucho de lo obtenido en el TP anterior para "curar" nuestro dataset con diferentes recetas. Por curar nos referimos a generar los procesos necesarios (trazables y reproducibles) que nos lleven del conjunto original de datos (que debe permanecer inmutable) hasta un conjunto que pueda ser consumido por distintos algorimos de aprendizaje. Las recetas pasaran de las mas simples, hasta algunas mas elaboradas. Una de las intenciones de todo proceso de curacion es salvar, en base a ciertos supuestos, la mayor cantidad de datos (puesto que la recoleccion de los mismos, etc, suele ser un proceso costoso tanto en recursos como en tiempo, entre otras cosas).
#
# ### Fuentes
#
# El presente trabajo práctico está inspirado en los correspondientes de:
#
# - [jbergamasco2019](https://github.com/jbergamasco/DiploDatos2019)
#
# - [TP-Analisis-Visualizacion](https://github.com/felixlapalma/monitoreo-espacios-verdes-diplo202X/blob/main/notebooks-tp/Analisis-y-Visualizacion-MEV-TP.ipynb)
#
# Para una introducción un poco mas extensa respecto al origen de los datos y su procesamiento se pueden referir a :
# - [ab-initio-data-build](https://github.com/felixlapalma/monitoreo-espacios-verdes-diplo202X/blob/main/data/ab-initio-dataset-build.md)
# - [ab-initio-analisis-visualizacion](https://github.com/felixlapalma/monitoreo-espacios-verdes-diplo202X/blob/main/data/ab-initio-analisis-visualizacion.md)

# %% [markdown]
# ## Sobre el Trabajo Requerido
#
# Se propone la elaboración de un conjunto de procedimientos (\*.py o notebooks) que nos permitan partiendo del dataset original obtener uno nuevo y "curado".
# Respecto a las recetas mencionadas, son las que van a dar origen a los distintos procedimientos y nos van a permitir inferir (ya en el proximo TP) la importancia del proceso de curación.
#
# ### Sobre las recetas
#
# La idea de construccion de una receta es que pueda ser aprovechada cuando le llegue un set nuevo de datos. Tanto  para su transformacion para incorporarlos al set de entramiento como para su posible uso en inferencia.
#
# __DISCLAIMER__: En lo siguiente vamos a presentar un numero limitado (~4) de recetas (para el problema en cuestión).
#
# ### ab-initio
#
# - elija (basados en lo aprendido en el TP anterior) un conjunto de bandas e indices que considere representativo. Adicione a su elección:
#     - raster: raster del cual se extraen los estadísticos
#     - clouds_on_raster: nubosidad del raster completo
#     - osm_id: identificador asociado a la capa original (atlas-espacios-verdes)
#     - area_m2: area en metros cuadrados
#     - date: fecha de la muestra.
#
#     estas variables las sumamos a los efectos practicos de representacion y filtrado.
#
#
#
# ### [A] Esfuerzo Nulo

# %% [markdown]
# - Leer los datos

# %%
# Setup necesario para correr pandas profiling
# !pip install --upgrade pip
#!pip install pandas_profiling==2.8.0
# !pip install pandas-profiling[notebook]

# !pip install pandas_profiling  
# Run this from Jupytor notebook Ignore the warnings if any 
from pandas_profiling import ProfileReport 
#restart the kernel if throws error

########################################
# Importación necesaria para correr pandas profiling y descargar reporte
from pandas_profiling import ProfileReport
##from google.colab import files
########################################
# Descarga de base de datos
 #from link @ https://github.com/felixlapalma/monitoreo-espacios-verdes-diplo202X/blob/main/data/ab-initio-dataset-build.md
#########################################
# !pip install gdown
# !pip install missingno
# !pip install statsmodels
# Out:
# Requirement already satisfied: pip in c:\users\varios\anaconda3\lib\site-packages (22.1.2)
# Requirement already satisfied: pandas-profiling[notebook] in c:\users\varios\anaconda3\lib\site-packages (2.8.0)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.6 in c:\users\varios\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (0.2.0)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\varios\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (1.21.5)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\varios\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (2.11.3)
# Requirement already satisfied: missingno>=0.4.2 in c:\users\varios\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (0.5.1)
# Requirement already satisfied: joblib in c:\users\varios\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (1.1.0)
# Requirement already satisfied: htmlmin>=0.1.12 in c:\users\varios\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (0.1.12)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\varios\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (3.5.1)
# Requirement already satisfied: tqdm>=4.43.0 in c:\users\varios\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (4.64.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\varios\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (1.7.3)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in c:\users\varios\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (1.2.0)
# Requirement already satisfied: requests>=2.23.0 in c:\users\varios\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (2.27.1)
# Requirement already satisfied: phik>=0.9.10 in c:\users\varios\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (0.12.2)
# Requirement already satisfied: visions[type_image_path]==0.4.4 in c:\users\varios\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (0.4.4)
# Requirement already satisfied: astropy>=4.0 in c:\users\varios\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (5.0.4)
# Requirement already satisfied: confuse>=1.0.0 in c:\users\varios\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (1.7.0)
# Requirement already satisfied: ipywidgets>=7.5.1 in c:\users\varios\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (7.6.5)
# Requirement already satisfied: jupyter-client>=6.0.0 in c:\users\varios\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (6.1.12)
# Requirement already satisfied: jupyter-core>=4.6.3 in c:\users\varios\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (4.9.2)
# Requirement already satisfied: networkx>=2.4 in c:\users\varios\anaconda3\lib\site-packages (from visions[type_image_path]==0.4.4->pandas-profiling[notebook]) (2.7.1)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\varios\anaconda3\lib\site-packages (from visions[type_image_path]==0.4.4->pandas-profiling[notebook]) (21.4.0)
# Requirement already satisfied: Pillow in c:\users\varios\anaconda3\lib\site-packages (from visions[type_image_path]==0.4.4->pandas-profiling[notebook]) (9.0.1)
# Requirement already satisfied: imagehash in c:\users\varios\anaconda3\lib\site-packages (from visions[type_image_path]==0.4.4->pandas-profiling[notebook]) (4.2.1)
# Requirement already satisfied: pyerfa>=2.0 in c:\users\varios\anaconda3\lib\site-packages (from astropy>=4.0->pandas-profiling[notebook]) (2.0.0)
# Requirement already satisfied: PyYAML>=3.13 in c:\users\varios\anaconda3\lib\site-packages (from astropy>=4.0->pandas-profiling[notebook]) (6.0)
# Requirement already satisfied: packaging>=19.0 in c:\users\varios\anaconda3\lib\site-packages (from astropy>=4.0->pandas-profiling[notebook]) (21.3)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\varios\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\varios\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\varios\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (3.5.2)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\varios\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (6.9.1)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\varios\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (5.1.1)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\varios\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (8.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\varios\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (5.3.0)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\varios\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\varios\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.5.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\varios\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling[notebook]) (6.1)
# Requirement already satisfied: nest-asyncio in c:\users\varios\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.5.5)
# Requirement already satisfied: decorator in c:\users\varios\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (5.1.1)
# Requirement already satisfied: backcall in c:\users\varios\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\varios\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.7.5)
# Requirement already satisfied: stack-data in c:\users\varios\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\varios\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (3.0.20)
# Requirement already satisfied: setuptools>=18.5 in c:\users\varios\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (61.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\varios\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.18.1)
# Requirement already satisfied: colorama in c:\users\varios\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.4.4)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\varios\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (2.11.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\varios\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.8.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\varios\anaconda3\lib\site-packages (from jinja2>=2.11.1->pandas-profiling[notebook]) (2.0.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\varios\anaconda3\lib\site-packages (from jupyter-client>=6.0.0->pandas-profiling[notebook]) (22.3.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\varios\anaconda3\lib\site-packages (from jupyter-client>=6.0.0->pandas-profiling[notebook]) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\varios\anaconda3\lib\site-packages (from jupyter-core>=4.6.3->pandas-profiling[notebook]) (302)
# Requirement already satisfied: cycler>=0.10 in c:\users\varios\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling[notebook]) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\varios\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling[notebook]) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\varios\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling[notebook]) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\varios\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling[notebook]) (4.25.0)
# Requirement already satisfied: seaborn in c:\users\varios\anaconda3\lib\site-packages (from missingno>=0.4.2->pandas-profiling[notebook]) (0.11.2)
# Requirement already satisfied: fastjsonschema in c:\users\varios\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (2.15.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\varios\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (4.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\varios\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.18.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\varios\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->pandas-profiling[notebook]) (2021.3)
# Requirement already satisfied: wcwidth in c:\users\varios\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\varios\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client>=6.0.0->pandas-profiling[notebook]) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\varios\anaconda3\lib\site-packages (from requests>=2.23.0->pandas-profiling[notebook]) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\varios\anaconda3\lib\site-packages (from requests>=2.23.0->pandas-profiling[notebook]) (2022.6.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\varios\anaconda3\lib\site-packages (from requests>=2.23.0->pandas-profiling[notebook]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\varios\anaconda3\lib\site-packages (from requests>=2.23.0->pandas-profiling[notebook]) (3.3)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\varios\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (6.4.8)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\varios\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.13.1)
# Requirement already satisfied: prometheus-client in c:\users\varios\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.13.1)
# Requirement already satisfied: nbconvert in c:\users\varios\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (6.4.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\varios\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.8.0)
# Requirement already satisfied: argon2-cffi in c:\users\varios\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (21.3.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\varios\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\varios\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\varios\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\varios\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (2.21)
# Requirement already satisfied: PyWavelets in c:\users\varios\anaconda3\lib\site-packages (from imagehash->visions[type_image_path]==0.4.4->pandas-profiling[notebook]) (1.3.0)
# Requirement already satisfied: defusedxml in c:\users\varios\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\varios\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.1.2)
# Requirement already satisfied: testpath in c:\users\varios\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.5.0)
# Requirement already satisfied: bleach in c:\users\varios\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (4.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\varios\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.5.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\varios\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (4.11.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\varios\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\varios\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.5.13)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\varios\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.8.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\varios\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\varios\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.5.1)
# Requirement already satisfied: executing in c:\users\varios\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\varios\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\varios\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.2.2)
# Requirement already satisfied: pandas_profiling in c:\users\varios\anaconda3\lib\site-packages (2.8.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\varios\anaconda3\lib\site-packages (from pandas_profiling) (1.7.3)
# Requirement already satisfied: htmlmin>=0.1.12 in c:\users\varios\anaconda3\lib\site-packages (from pandas_profiling) (0.1.12)
# Requirement already satisfied: missingno>=0.4.2 in c:\users\varios\anaconda3\lib\site-packages (from pandas_profiling) (0.5.1)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.6 in c:\users\varios\anaconda3\lib\site-packages (from pandas_profiling) (0.2.0)
# Requirement already satisfied: tqdm>=4.43.0 in c:\users\varios\anaconda3\lib\site-packages (from pandas_profiling) (4.64.0)
# Requirement already satisfied: visions[type_image_path]==0.4.4 in c:\users\varios\anaconda3\lib\site-packages (from pandas_profiling) (0.4.4)
# Requirement already satisfied: phik>=0.9.10 in c:\users\varios\anaconda3\lib\site-packages (from pandas_profiling) (0.12.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\varios\anaconda3\lib\site-packages (from pandas_profiling) (2.27.1)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\varios\anaconda3\lib\site-packages (from pandas_profiling) (2.11.3)
# Requirement already satisfied: ipywidgets>=7.5.1 in c:\users\varios\anaconda3\lib\site-packages (from pandas_profiling) (7.6.5)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in c:\users\varios\anaconda3\lib\site-packages (from pandas_profiling) (1.2.0)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\varios\anaconda3\lib\site-packages (from pandas_profiling) (3.5.1)
# Requirement already satisfied: joblib in c:\users\varios\anaconda3\lib\site-packages (from pandas_profiling) (1.1.0)
# Requirement already satisfied: confuse>=1.0.0 in c:\users\varios\anaconda3\lib\site-packages (from pandas_profiling) (1.7.0)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\varios\anaconda3\lib\site-packages (from pandas_profiling) (1.21.5)
# Requirement already satisfied: astropy>=4.0 in c:\users\varios\anaconda3\lib\site-packages (from pandas_profiling) (5.0.4)
# Requirement already satisfied: networkx>=2.4 in c:\users\varios\anaconda3\lib\site-packages (from visions[type_image_path]==0.4.4->pandas_profiling) (2.7.1)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\varios\anaconda3\lib\site-packages (from visions[type_image_path]==0.4.4->pandas_profiling) (21.4.0)
# Requirement already satisfied: imagehash in c:\users\varios\anaconda3\lib\site-packages (from visions[type_image_path]==0.4.4->pandas_profiling) (4.2.1)
# Requirement already satisfied: Pillow in c:\users\varios\anaconda3\lib\site-packages (from visions[type_image_path]==0.4.4->pandas_profiling) (9.0.1)
# Requirement already satisfied: PyYAML>=3.13 in c:\users\varios\anaconda3\lib\site-packages (from astropy>=4.0->pandas_profiling) (6.0)
# Requirement already satisfied: pyerfa>=2.0 in c:\users\varios\anaconda3\lib\site-packages (from astropy>=4.0->pandas_profiling) (2.0.0)
# Requirement already satisfied: packaging>=19.0 in c:\users\varios\anaconda3\lib\site-packages (from astropy>=4.0->pandas_profiling) (21.3)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\varios\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_profiling) (5.3.0)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\varios\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_profiling) (8.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\varios\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_profiling) (1.0.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\varios\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_profiling) (5.1.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\varios\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_profiling) (3.5.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\varios\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_profiling) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\varios\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_profiling) (6.9.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\varios\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_profiling) (6.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\varios\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_profiling) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\varios\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_profiling) (1.5.1)
# Requirement already satisfied: nest-asyncio in c:\users\varios\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_profiling) (1.5.5)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\varios\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_profiling) (6.1.12)
# Requirement already satisfied: backcall in c:\users\varios\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_profiling) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\varios\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_profiling) (61.2.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\varios\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_profiling) (2.11.2)
# Requirement already satisfied: decorator in c:\users\varios\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_profiling) (5.1.1)
# Requirement already satisfied: stack-data in c:\users\varios\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_profiling) (0.2.0)
# Requirement already satisfied: colorama in c:\users\varios\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_profiling) (0.4.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\varios\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_profiling) (3.0.20)
# Requirement already satisfied: pickleshare in c:\users\varios\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_profiling) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\varios\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_profiling) (0.18.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\varios\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5.1->pandas_profiling) (0.8.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\varios\anaconda3\lib\site-packages (from jinja2>=2.11.1->pandas_profiling) (2.0.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\varios\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_profiling) (22.3.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\varios\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_profiling) (4.9.2)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\varios\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_profiling) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\varios\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_profiling) (302)
# Requirement already satisfied: cycler>=0.10 in c:\users\varios\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\varios\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\varios\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\varios\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (3.0.4)
# Requirement already satisfied: seaborn in c:\users\varios\anaconda3\lib\site-packages (from missingno>=0.4.2->pandas_profiling) (0.11.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\varios\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas_profiling) (4.4.0)
# Requirement already satisfied: fastjsonschema in c:\users\varios\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas_profiling) (2.15.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\varios\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.5.1->pandas_profiling) (0.18.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\varios\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->pandas_profiling) (2021.3)
# Requirement already satisfied: wcwidth in c:\users\varios\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5.1->pandas_profiling) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\varios\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_profiling) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\varios\anaconda3\lib\site-packages (from requests>=2.23.0->pandas_profiling) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\varios\anaconda3\lib\site-packages (from requests>=2.23.0->pandas_profiling) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\varios\anaconda3\lib\site-packages (from requests>=2.23.0->pandas_profiling) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\varios\anaconda3\lib\site-packages (from requests>=2.23.0->pandas_profiling) (2022.6.15)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\varios\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (6.4.8)
# Requirement already satisfied: nbconvert in c:\users\varios\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (6.4.4)
# Requirement already satisfied: prometheus-client in c:\users\varios\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (0.13.1)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\varios\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (0.13.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\varios\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (1.8.0)
# Requirement already satisfied: argon2-cffi in c:\users\varios\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (21.3.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\varios\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\varios\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\varios\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\varios\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (2.21)
# Requirement already satisfied: PyWavelets in c:\users\varios\anaconda3\lib\site-packages (from imagehash->visions[type_image_path]==0.4.4->pandas_profiling) (1.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\varios\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (0.8.4)
# Requirement already satisfied: testpath in c:\users\varios\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (0.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\varios\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (0.5.13)
# Requirement already satisfied: beautifulsoup4 in c:\users\varios\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (4.11.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\varios\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (0.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\varios\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (1.5.0)
# Requirement already satisfied: bleach in c:\users\varios\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\varios\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\varios\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (0.1.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\varios\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\varios\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (0.5.1)
# Requirement already satisfied: pure-eval in c:\users\varios\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->pandas_profiling) (0.2.2)
# Requirement already satisfied: executing in c:\users\varios\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->pandas_profiling) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\varios\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->pandas_profiling) (2.0.5)
# Requirement already satisfied: gdown in c:\users\varios\anaconda3\lib\site-packages (4.4.0)
# Requirement already satisfied: filelock in c:\users\varios\anaconda3\lib\site-packages (from gdown) (3.6.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\varios\anaconda3\lib\site-packages (from gdown) (4.11.1)
# Requirement already satisfied: six in c:\users\varios\anaconda3\lib\site-packages (from gdown) (1.16.0)
# Requirement already satisfied: requests[socks] in c:\users\varios\anaconda3\lib\site-packages (from gdown) (2.27.1)
# Requirement already satisfied: tqdm in c:\users\varios\anaconda3\lib\site-packages (from gdown) (4.64.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\varios\anaconda3\lib\site-packages (from beautifulsoup4->gdown) (2.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\varios\anaconda3\lib\site-packages (from requests[socks]->gdown) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\varios\anaconda3\lib\site-packages (from requests[socks]->gdown) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\varios\anaconda3\lib\site-packages (from requests[socks]->gdown) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\varios\anaconda3\lib\site-packages (from requests[socks]->gdown) (2.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\varios\anaconda3\lib\site-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: colorama in c:\users\varios\anaconda3\lib\site-packages (from tqdm->gdown) (0.4.4)
# Requirement already satisfied: missingno in c:\users\varios\anaconda3\lib\site-packages (0.5.1)
# Requirement already satisfied: scipy in c:\users\varios\anaconda3\lib\site-packages (from missingno) (1.7.3)
# Requirement already satisfied: numpy in c:\users\varios\anaconda3\lib\site-packages (from missingno) (1.21.5)
# Requirement already satisfied: matplotlib in c:\users\varios\anaconda3\lib\site-packages (from missingno) (3.5.1)
# Requirement already satisfied: seaborn in c:\users\varios\anaconda3\lib\site-packages (from missingno) (0.11.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\varios\anaconda3\lib\site-packages (from matplotlib->missingno) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\varios\anaconda3\lib\site-packages (from matplotlib->missingno) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\varios\anaconda3\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\varios\anaconda3\lib\site-packages (from matplotlib->missingno) (9.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\varios\anaconda3\lib\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\varios\anaconda3\lib\site-packages (from matplotlib->missingno) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\varios\anaconda3\lib\site-packages (from matplotlib->missingno) (3.0.4)
# Requirement already satisfied: six>=1.5 in c:\users\varios\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# Requirement already satisfied: pandas>=0.23 in c:\users\varios\anaconda3\lib\site-packages (from seaborn->missingno) (1.2.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\varios\anaconda3\lib\site-packages (from pandas>=0.23->seaborn->missingno) (2021.3)
# Requirement already satisfied: statsmodels in c:\users\varios\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\varios\anaconda3\lib\site-packages (from statsmodels) (1.21.5)
# Requirement already satisfied: scipy>=1.3 in c:\users\varios\anaconda3\lib\site-packages (from statsmodels) (1.7.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\varios\anaconda3\lib\site-packages (from statsmodels) (1.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\varios\anaconda3\lib\site-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\varios\anaconda3\lib\site-packages (from statsmodels) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\varios\anaconda3\lib\site-packages (from packaging>=21.3->statsmodels) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\varios\anaconda3\lib\site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\varios\anaconda3\lib\site-packages (from pandas>=0.25->statsmodels) (2021.3)
# Requirement already satisfied: six in c:\users\varios\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)

# %%
# Descarga de archivo
# !gdown https://drive.google.com/file/d/1tgbIQaEXzIghcFYyd2YM9iMho4TDHHFd/view?usp=sharing --fuzzy
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1tgbIQaEXzIghcFYyd2YM9iMho4TDHHFd
# To: C:\Users\Varios\Mentoria - practicos\espacios-verdes-indexs-cba-20170101-20220420.zip
#
#   0%|          | 0.00/170M [00:00<?, ?B/s]
#   0%|          | 524k/170M [00:00<01:52, 1.51MB/s]
#   1%|          | 1.05M/170M [00:00<01:45, 1.60MB/s]
#   1%|          | 1.57M/170M [00:00<01:46, 1.58MB/s]
#   1%|1         | 2.10M/170M [00:01<01:45, 1.60MB/s]
#   2%|1         | 2.62M/170M [00:01<01:47, 1.56MB/s]
#   2%|1         | 3.15M/170M [00:01<01:46, 1.57MB/s]
#   2%|2         | 3.67M/170M [00:02<01:45, 1.58MB/s]
#   2%|2         | 4.19M/170M [00:02<01:45, 1.57MB/s]
#   3%|2         | 4.72M/170M [00:02<01:42, 1.62MB/s]
#   3%|3         | 5.24M/170M [00:03<01:39, 1.66MB/s]
#   3%|3         | 5.77M/170M [00:03<01:38, 1.67MB/s]
#   4%|3         | 6.29M/170M [00:03<01:38, 1.67MB/s]
#   4%|4         | 6.82M/170M [00:04<01:37, 1.67MB/s]
#   4%|4         | 7.34M/170M [00:04<01:37, 1.67MB/s]
#   5%|4         | 7.86M/170M [00:04<01:36, 1.67MB/s]
#   5%|4         | 8.39M/170M [00:05<01:35, 1.70MB/s]
#  99%|#########8| 168M/170M [01:38<00:01, 1.74MB/s]
#  99%|#########8| 168M/170M [01:38<00:01, 1.72MB/s]
#  99%|#########9| 169M/170M [01:38<00:00, 1.72MB/s]
#  99%|#########9| 169M/170M [01:39<00:00, 1.73MB/s]
# 100%|#########9| 170M/170M [01:39<00:00, 1.74MB/s]
# 100%|##########| 170M/170M [01:39<00:00, 1.59MB/s]
# 100%|##########| 170M/170M [01:39<00:00, 1.71MB/s]

# %%
df_=pd.read_csv("C:/Users/Varios/Desktop/Diplodatos/Mentoria/espacios-verdes-indexs-cba-20170101-20220420.zip",index_col=0)
display(df_.head())

# Lectura de csv y obtención de dataframe 
#df_=pd.read_csv(r"C:\Users\Sebastian\Documents\buckup 20-4-2021\4- Data Science\Diplo FAMAF\Espacios verdes\espacios-verdes-indexs-cba-20170101-20220420.zip", index_col=0)
#df_
# Out:
#    B02_min  B02_max  B02_mean  B02_median  B02_nodata  B02_range  B02_count  \
# 0   0.0871   0.1421  0.102570     0.09650         0.0     0.0550         47
# 1   0.0970   0.1936  0.118354     0.10660         0.0     0.0966         13
# 2   0.0992   0.1273  0.111805     0.11290         0.0     0.0281         19
# 3   0.0995   0.1933  0.118491     0.11355         0.0     0.0938         66
# 4   0.1059   0.1385  0.122453     0.12240         0.0     0.0326         47
#
#    B03_min  B03_max  B03_mean  ...  sipi_median  sipi_nodata  sipi_range  \
# 0   0.0768   0.1516  0.098885  ...     0.884216          0.0    0.453065
# 1   0.1006   0.1949  0.122154  ...     0.971875          0.0    0.247045
# 2   0.1037   0.1369  0.117795  ...     0.973017          0.0    0.207006
# 3   0.0993   0.1990  0.124512  ...     0.966202          0.0    0.258424
# 4   0.1036   0.1580  0.132455  ...     0.993986          0.0    0.260419
#
#    sipi_count                                             raster  \
# 0          47  S2A_MSIL1C_20170103T142022_N0204_R010_T20JLL_2...
# 1          13  S2A_MSIL1C_20170103T142022_N0204_R010_T20JLL_2...
# 2          19  S2A_MSIL1C_20170103T142022_N0204_R010_T20JLL_2...
# 3          66  S2A_MSIL1C_20170103T142022_N0204_R010_T20JLL_2...
# 4          47  S2A_MSIL1C_20170103T142022_N0204_R010_T20JLL_2...
#
#    clouds_on_raster     osm_id  name      area_m2        date
# 0               0.0  605976736   NaN  4650.710032  2017-01-03
# 1               0.0  559322368   NaN  1502.000513  2017-01-03
# 2               0.0  559322369   NaN  2004.192528  2017-01-03
# 3               0.0  559328111   NaN  6940.507640  2017-01-03
# 4               0.0  559328112   NaN  4587.356048  2017-01-03
#
# [5 rows x 167 columns]

# %%
df_.info()
df_.shape
df_.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 208932 entries, 0 to 208931
# Columns: 167 entries, B02_min to date
# dtypes: float64(140), int64(24), object(3)
# memory usage: 267.8+ MB
# Index(['B02_min', 'B02_max', 'B02_mean', 'B02_median', 'B02_nodata',
#        'B02_range', 'B02_count', 'B03_min', 'B03_max', 'B03_mean',
#        ...
#        'sipi_median', 'sipi_nodata', 'sipi_range', 'sipi_count', 'raster',
#        'clouds_on_raster', 'osm_id', 'name', 'area_m2', 'date'],
#       dtype='object', length=167)

# %% [markdown]
# - Extraer las columnas de interes (## ab-initio)

# %%
# Creamos un nuevo dataframe con las columnas de interés 
df_interest_A1 = df_[["B02_median", "B06_median", "B11_median","osm_id", "date", "ndvi_max", "area_m2","raster","clouds_on_raster"]]
len(df_interest_A1)
df_interest_A1.shape
df_interest_A1=pd.DataFrame(df_interest_A1)

# %%
df_interest_A1["id"] = df_interest_A1.index + 1
df_interest_A1['date']= pd.to_datetime(df_interest_A1['date'])
df_interest_A1['date1'] = df_interest_A1['date']
df_interest_A1 = df_interest_A1.set_index('date')
df_interest_A1
# Out:
#             B02_median  B06_median  B11_median     osm_id  ndvi_max  \
# date
# 2017-01-03     0.09650     0.19910     0.18770  605976736  0.630881
# 2017-01-03     0.10660     0.25960     0.25420  559322368  0.630041
# 2017-01-03     0.11290     0.25550     0.24640  559322369  0.622036
# 2017-01-03     0.11355     0.29300     0.26675  559328111  0.669891
# 2017-01-03     0.12240     0.29460     0.28950  559328112  0.619112
# ...                ...         ...         ...        ...       ...
# 2022-04-17     0.11270     0.20520     0.18950  307532496  0.563955
# 2022-04-17     0.13665     0.23835     0.27315  307535460  0.490798
# 2022-04-17     0.10625     0.22425     0.22230  307796387  0.566516
# 2022-04-17     0.12570     0.20880     0.25450  307097955  0.534379
# 2022-04-17     0.10180     0.19080     0.19740  901791744  0.635997
#
#                 area_m2                                             raster  \
# date
# 2017-01-03  4650.710032  S2A_MSIL1C_20170103T142022_N0204_R010_T20JLL_2...
# 2017-01-03  1502.000513  S2A_MSIL1C_20170103T142022_N0204_R010_T20JLL_2...
# 2017-01-03  2004.192528  S2A_MSIL1C_20170103T142022_N0204_R010_T20JLL_2...
# 2017-01-03  6940.507640  S2A_MSIL1C_20170103T142022_N0204_R010_T20JLL_2...
# 2017-01-03  4587.356048  S2A_MSIL1C_20170103T142022_N0204_R010_T20JLL_2...
# ...                 ...                                                ...
# 2022-04-17  3824.467794  S2A_MSIL1C_20220417T141741_N0400_R010_T20JLL_2...
# 2022-04-17  7184.535857  S2A_MSIL1C_20220417T141741_N0400_R010_T20JLL_2...
# 2022-04-17  1147.997645  S2A_MSIL1C_20220417T141741_N0400_R010_T20JLL_2...
# 2022-04-17  5185.690046  S2A_MSIL1C_20220417T141741_N0400_R010_T20JLL_2...
# 2022-04-17  9394.381202  S2A_MSIL1C_20220417T141741_N0400_R010_T20JLL_2...
#
#             clouds_on_raster      id      date1
# date
# 2017-01-03               0.0       1 2017-01-03
# 2017-01-03               0.0       2 2017-01-03
# 2017-01-03               0.0       3 2017-01-03
# 2017-01-03               0.0       4 2017-01-03
# 2017-01-03               0.0       5 2017-01-03
# ...                      ...     ...        ...
# 2022-04-17               0.0  208928 2022-04-17
# 2022-04-17               0.0  208929 2022-04-17
# 2022-04-17               0.0  208930 2022-04-17
# 2022-04-17               0.0  208931 2022-04-17
# 2022-04-17               0.0  208932 2022-04-17
#
# [208932 rows x 10 columns]

# %%
plt.figure(figsize=(30,10))
from matplotlib import style
########  
# using the style for the plot
plt.style.use('Solarize_Light2')
########  
plt.plot(df_interest_A1['B02_median'], 'b.', label = 'B02 MEDIAN',linewidth=0.5,alpha=0.8)
plt.plot(df_interest_A1['B06_median'], 'r.', label = 'B06 MEDIAN',linewidth=0.5,alpha=0.5)
plt.plot(df_interest_A1['B11_median'], 'y.', label = 'B11 MEDIAN',linewidth=0.5,alpha=0.1)
plt.legend()
plt.figure()

# %%
plt.style.use('ggplot')

plt.figure(figsize=(60,20))
plt.plot(df_interest_A1['clouds_on_raster'], 'b.', label = 'Clouds on raster',linewidth=1,alpha=0.9)
plt.legend()
plt.figure()

# %%
# Utilizamos la librería missingno para el análisis de datos faltantes 
import missingno as msno

# %%
# Graficamos los datos faltantes de varias variables, incluidas las de interés
msno.bar(df_interest_A1,figsize=(14,6), sort="ascending",fontsize=12, color='tomato')
# Out:
# <AxesSubplot:>

# %%
msno.matrix(df_interest_A1,figsize=(10, 4), fontsize=12, color=[0,0,0.2])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Sugerencia
#
# Considere cada paso de la receta como una función. Es decir al finalizar una receta tendra tantas funciones como pasos. Esto le va a permitir reordenar y reutilizar las mismas sin necesidad de reescribir ningun codigo extra. Esto le sera particularmente util para una de las preguntas de la siguiente sección.
#
#
# ## Recetas + Comparativa
#
# Una vez generadas las recetas se debera generar una suerte de tabla comparativa entre las mismas, poniendo de relevancia la cantidad de datos desechados/recuperados en cada instancia. _Note que todos las recetas tienen un mismo eje_.
#
# ¿Cual es su percepcion de como resultaran cada una de las recetas en un algoritmo de aprendizaje?
#
# ¿Que pasa si en la receta [C] o [D] primero filtra por nubosidad y despues remueve outliers? Considere esto como variante y definalo como [C-1] y [C-2] ([D-1]/[D-2]).

# %% [markdown]
# ## __Extra__
#
# Generar alguna receta alternativa, basada en las propuestas mencionadas (o alguna completamente diferente :-) ).

# %%
# Desarrollar aquí receta alternativa

# %% [markdown]
# Receta con descomposición de serie de tiempo
#
# #Bajo esta alternativa se remueven los outliers a partir de las variaciones observadas en el componente "ruido" de la serie de tiempo.
#
# #Primero se prueba con 5 métodos alternativos de imputación de valores nulos.
#
# #Luego se descompone la serie en tendencia, estacionalidad y ruido suponiendo que está modelada de forma : aditiva  dado que la serie de tiempo sería estacionaria.
#
# #El modelo aditivo es apropiado cuando la magnitud de las
# #fluctuaciones estacionales de la serie no varıa al hacerlo la tendencia.
#
# #y_i = t_i + s_i + n_i
#
# #where y_i = el valor que asume la serie de tiempo en el momento i.
# #t_i = el componente tendencia en el momento i -presenta las variaciones a largo plazo-.
# #s_i = el componente estacional en el momento i -releja las variaciones a corto plazo-.
# #n_i = el ruido en el momenot i.
#
# #El modelo multiplicativo es apropiado cuando la magnitud de las
# #fluctuaciones estacionales de la serie crece y decrece
# #proporcionalmente con los crecimientos y decrecimientos
# #de la tendencia, respectivamente.
#
# #y_i = t_i * s_i * n_i
# ################################################################

# %%
# Dado que la lectura de datos y extracción de columnas ya se realizó anteriormente, generamos un nuevo dataframe para 
# procesar, en base a df_interest. Este contiene las columnas de interés pero sin ningún procesamiento.
df_interest_extra2 = df_interest_A1.copy()
len(df_interest_extra2)
# Out:
# 208932

# %%
from statsmodels.tsa import seasonal
import numpy as np
import pandas as pd

# %%
df_interest_extra2.describe()
# Out:
#           B02_median     B06_median     B11_median        osm_id  \
# count  167269.000000  167264.000000  167262.000000  2.089320e+05
# mean        0.129623       0.217933       0.238991  4.343631e+08
# std         0.035332       0.044101       0.057024  2.141069e+08
# min         0.061900       0.040500       0.021300  1.331006e+06
# 25%         0.110300       0.191700       0.204150  2.867065e+08
# 50%         0.122800       0.217450       0.238100  3.596742e+08
# 75%         0.137800       0.241400       0.274000  6.059767e+08
# max         0.689700       0.784500       0.806100  9.249657e+08
#
#             ndvi_max       area_m2  clouds_on_raster             id
# count  167260.000000  2.089320e+05     208932.000000  208932.000000
# mean        0.501846  1.249388e+04         19.473638  104466.500000
# std         0.137381  7.895730e+04         33.424013   60313.617559
# min        -0.194614  4.225951e+02          0.000000       1.000000
# 25%         0.408413  2.066559e+03          0.000000   52233.750000
# 50%         0.516362  3.812182e+03          0.000000  104466.500000
# 75%         0.609126  6.644794e+03         25.009939  156699.250000
# max         0.999486  1.370630e+06        100.000000  208932.000000

# %% [markdown]
# La elección del método de imputación, requiere del conocimiento de la naturaleza del problema de los datos que faltan en el dataset a imputar. Como vimos en el práctico pasado, es posible que la falta de registros en este dataset sea debido a un error no aleatorio correspondiente a características no observadas. Esto acota la disponibilidad de métodos de imputación. Podríamos considerar el uso de técnicas como KNN (vecino más cercano). Sin embargo, para la imputación de valores faltantes en una variable dada, KNN define con mayor precisión los vecinos cercanos si se utilizan variables de soporte que contengan datos para el mismo registro donde faltan datos en la variable dada. En el caso de este dataset, lamentablemente, los registros que faltan para una variable, son los mismos que para las otras, impidiendo una estimación adecuada por KNN. Esto puede verse claramente en la siguiente gráfica.
# Bajo esta receta se prueba cuatro métodos alternativos y finalmente optamos por imputar por el método spline.

# %%
##Imputación de valores faltantes con métodos alternativos
df_interest_extra2[['B02_median_imp_linear', 'B06_median_imp_linear','B11_median_imp_linear','ndvi_max_imp_linear']]=df_interest_extra2[['B02_median', 'B06_median','B11_median','ndvi_max']].interpolate(method='linear')    
df_interest_extra2[['B02_median_imp_slinear', 'B06_median_imp_slinear','B11_median_imp_slinear','ndvi_max_imp_slinear']]=df_interest_extra2[['B02_median', 'B06_median','B11_median','ndvi_max']].interpolate(method='slinear')    
df_interest_extra2[['B02_median_imp_time', 'B06_median_imp_time','B11_median_imp_time','ndvi_max_imp_time']]=df_interest_extra2[['B02_median', 'B06_median','B11_median','ndvi_max']].interpolate(method='time')    

#########################
##La herramienta Spline utiliza un método de interpolación que estima valores usando una 
##función matemática que minimiza la curvatura general de la superficie, 
##lo que resulta en una superficie suave que pasa exactamente por los puntos de entrada.
df_interest_extra2[['B02_median_imp_spline5', 'B06_median_imp_spline5','B11_median_imp_spline5','ndvi_max_imp_spline5']]=df_interest_extra2[['B02_median', 'B06_median','B11_median','ndvi_max']].interpolate(method='spline',order=5)    
df_interest_extra2
###########################
#####################
msno.bar(df_interest_extra2,figsize=(14,6), sort="ascending",fontsize=12, color='tomato')
# Out:
# <AxesSubplot:>

# %%
###Ejemplo de gráfico con imputaciones para B02_median

from matplotlib import style
###
#plt.style.use('Solarize_Light2')
plt.subplot(3, 2,1)
plt.plot(df_interest_extra2['B02_median'],linewidth=0.5,alpha=0.9)
####
plt.subplot(3,2,2)
plt.plot(df_interest_extra2['B02_median_imp_linear'],linewidth=0.7,alpha=0.9)
###
plt.subplot(3,2,3)
plt.plot(df_interest_extra2['B02_median_imp_slinear'],linewidth=0.7,alpha=0.9)
###
plt.subplot(3,2,4)
plt.plot(df_interest_extra2['B02_median_imp_time'],linewidth=0.7,alpha=0.9)
####
plt.subplot(3,2,5)
plt.plot(df_interest_extra2['B02_median_imp_spline5'],linewidth=0.7,alpha=0.9)

plt.show()

# %%
df_interest_extra2.describe()
# Out:
#           B02_median     B06_median     B11_median        osm_id  \
# count  167269.000000  167264.000000  167262.000000  2.089320e+05
# mean        0.129623       0.217933       0.238991  4.343631e+08
# std         0.035332       0.044101       0.057024  2.141069e+08
# min         0.061900       0.040500       0.021300  1.331006e+06
# 25%         0.110300       0.191700       0.204150  2.867065e+08
# 50%         0.122800       0.217450       0.238100  3.596742e+08
# 75%         0.137800       0.241400       0.274000  6.059767e+08
# max         0.689700       0.784500       0.806100  9.249657e+08
#
#             ndvi_max       area_m2  clouds_on_raster             id  \
# count  167260.000000  2.089320e+05     208932.000000  208932.000000
# mean        0.501846  1.249388e+04         19.473638  104466.500000
# std         0.137381  7.895730e+04         33.424013   60313.617559
# min        -0.194614  4.225951e+02          0.000000       1.000000
# 25%         0.408413  2.066559e+03          0.000000   52233.750000
# 50%         0.516362  3.812182e+03          0.000000  104466.500000
# 75%         0.609126  6.644794e+03         25.009939  156699.250000
# max         0.999486  1.370630e+06        100.000000  208932.000000
#
#        B02_median_imp_linear  B06_median_imp_linear  ...  \
# count          208932.000000          208932.000000  ...
# mean                0.136633               0.221460  ...
# std                 0.042645               0.047007  ...
# min                 0.061900               0.040500  ...
# 25%                 0.112100               0.192700  ...
# 50%                 0.125843               0.219450  ...
# 75%                 0.143450               0.245250  ...
# max                 0.689700               0.784500  ...
#
#        B11_median_imp_slinear  ndvi_max_imp_slinear  B02_median_imp_time  \
# count           208932.000000         208932.000000        208932.000000
# mean                 0.241947              0.486419             0.135612
# std                  0.058779              0.143975             0.044098
# min                  0.021300             -0.194614             0.061900
# 25%                  0.206275              0.390037             0.111823
# 50%                  0.241550              0.504179             0.123900
# 75%                  0.278367              0.597739             0.140850
# max                  0.806100              0.999486             0.689700
#
#        B06_median_imp_time  B11_median_imp_time  ndvi_max_imp_time  \
# count        208932.000000        208932.000000      208932.000000
# mean              0.220299             0.238984           0.491309
# std               0.048815             0.059990           0.144563
# min               0.040500             0.021300          -0.194614
# 25%               0.191200             0.202450           0.400407
# 50%               0.218250             0.236750           0.504539
# 75%               0.245100             0.276300           0.601955
# max               0.784500             0.806100           0.999486
#
#        B02_median_imp_spline5  B06_median_imp_spline5  B11_median_imp_spline5  \
# count           208932.000000           208932.000000           208932.000000
# mean                 0.129448                0.218004                0.238815
# std                  0.031723                0.039565                0.051152
# min                  0.061900                0.040500                0.021300
# 25%                  0.113100                0.198900                0.212402
# 50%                  0.126130                0.217450                0.238037
# 75%                  0.135068                0.235900                0.264000
# max                  0.689700                0.784500                0.806100
#
#        ndvi_max_imp_spline5
# count         208932.000000
# mean               0.502826
# std                0.123984
# min               -0.194614
# 25%                0.437878
# 50%                0.511299
# 75%                0.589623
# max                0.999486
#
# [8 rows x 24 columns]

# %%
# Multiplicative Decomposition B02_MEDIAN
#result_mul_B02 = seasonal.seasonal_decompose(df_interest_extra2['B02_median_imp_spline5'], model='multiplicative',period=365)
# Additive Decomposition
result_add_B02 = seasonal.seasonal_decompose(df_interest_extra2['B02_median_imp_spline5'], model='additive',period=365)
# Plot
plt.rcParams.update({'figure.figsize': (30,20)})
#result_mul_B02.plot().suptitle('Multiplicative Decompose', fontsize=22)
result_add_B02.plot().suptitle('Additive Decompose', fontsize=22)
plt.show()

# %%
# Multiplicative Decomposition B06_MEDIAN
#result_mul_B06 = seasonal_decompose(df_interest_Z1_['B06_median'], model='multiplicative', period=365)
# Additive Decomposition
result_add_B06 = seasonal_decompose(df_interest_extra2['B06_median_imp_spline5'], model='additive', period=365)
# Plot
plt.rcParams.update({'figure.figsize': (30,10)})
#result_mul_B06.plot().suptitle('Multiplicative Decompose', fontsize=18)
result_add_B06.plot().suptitle('Additive Decompose', fontsize=18)
plt.show()
#########################################
# Multiplicative Decomposition B11_MEDIAN
#result_mul_B11 = seasonal_decompose(df_interest_Z1_['B11_median'], model='multiplicative', period=365)
# Additive Decomposition
result_add_B11 = seasonal_decompose(df_interest_extra2['B11_median_imp_spline5'], model='additive', period=365)
# Plot
plt.rcParams.update({'figure.figsize': (30,10)})
#result_mul_B11.plot().suptitle('Multiplicative Decompose', fontsize=18)
result_add_B11.plot().suptitle('Additive Decompose', fontsize=18)
plt.show()
#########################################
# Multiplicative Decomposition ndvi_max
#result_mul_ndvi_max = seasonal_decompose(df_interest_Z1['ndvi_max'], model='multiplicative', period=365)
# Additive Decomposition
result_add_ndvi_max = seasonal_decompose(df_interest_extra2['ndvi_max_imp_spline5'], model='additive', period=365)
# Plot
plt.rcParams.update({'figure.figsize': (30,10)})
#result_mul_ndvi_max.plot().suptitle('Multiplicative Decompose', fontsize=18)
result_add_ndvi_max.plot().suptitle('Additive Decompose', fontsize=18)
plt.show()

# %%
##########################################
##Se grafica el componente 'noise' ###
decomp_resid_B02 = result_add_B02.resid
ax = decomp_resid_B02.plot(figsize=(30, 5))
ax.set_xlabel('Date')
ax.set_ylabel('Residual of time series')
ax.set_title('Residual values of the time series B02_median')
plt.show()
#############
############
decomp_resid_B06 = result_add_B06.resid
ax = decomp_resid_B06.plot(figsize=(30, 5))
ax.set_xlabel('Date')
ax.set_ylabel('Residual of time series')
ax.set_title('Residual values of the time series B06_median')
plt.show()
#############
############
decomp_resid_B11 = result_add_B11.resid
ax = decomp_resid_B11.plot(figsize=(30, 5))
ax.set_xlabel('Date')
ax.set_ylabel('Residual of time series')
ax.set_title('Residual values of the time series B11_median')
plt.show()

#####
decomp_resid_ndvi_max = result_add_ndvi_max.resid
ax = decomp_resid_ndvi_max.plot(figsize=(30, 5))
ax.set_xlabel('Date')
ax.set_ylabel('Residual of time series')
ax.set_title('Residual values of the time series ndvi_max')
plt.show()

# %%
#####################################################################################
## A partir del compoenente "noise", se quitan aquellas observaciones con residuos extremos
###################
decomp_resid_B02=pd.DataFrame(decomp_resid_B02)
q1 = decomp_resid_B02['resid'].quantile(0.25)
q3 = decomp_resid_B02['resid'].quantile(0.75)
iqr = q3 - q1 
################
# calculamos límite superior e inferior
ls = q3 + 1.5 * iqr
li = q1 - 1.5 * iqr
# Generamos nueva columna
df_interest_extra2['out_B02']=np.where((decomp_resid_B02['resid'] >ls)|(decomp_resid_B02['resid'] < li),1,0)
df_interest_extra2                 

decomp_resid_B06=pd.DataFrame(decomp_resid_B06)
q1 = decomp_resid_B06['resid'].quantile(0.25)
q3 = decomp_resid_B06['resid'].quantile(0.75)
iqr = q3 - q1 
        # calculamos límite superior e inferior
ls = q3 + 1.5 * iqr
li = q1 - 1.5 * iqr

# Generamos nueva columna
df_interest_extra2['out_B06']=np.where((decomp_resid_B06['resid'] >ls)|(decomp_resid_B06['resid'] < li),1,0)
df_interest_extra2

decomp_resid_B11=pd.DataFrame(decomp_resid_B11)
q1 = decomp_resid_B11['resid'].quantile(0.25)
q3 = decomp_resid_B11['resid'].quantile(0.75)
iqr = q3 - q1 
# calculamos límite superior e inferior
ls = q3 + 1.5 * iqr
li = q1 - 1.5 * iqr
# Generamos nueva columna
df_interest_extra2['out_B11']=np.where((decomp_resid_B11['resid'] >ls)|(decomp_resid_B11['resid'] < li),1,0)
df_interest_extra2
######################################################################
decomp_resid_ndvi_max=pd.DataFrame(decomp_resid_ndvi_max)
q1 = decomp_resid_ndvi_max['resid'].quantile(0.25)
q3 = decomp_resid_ndvi_max['resid'].quantile(0.75)
iqr = q3 - q1 
# calculamos límite superior e inferior
ls = q3 + 1.5 * iqr
li = q1 - 1.5 * iqr
# Generamos nueva columna
df_interest_extra2['out_ndvi_max']=np.where((decomp_resid_ndvi_max['resid'] >ls)|(decomp_resid_ndvi_max['resid']< li),1,0)
df_interest_extra2
#######################################################
# Out:
#             B02_median  B06_median  B11_median     osm_id  ndvi_max  \
# date
# 2017-01-03     0.09650     0.19910     0.18770  605976736  0.630881
# 2017-01-03     0.10660     0.25960     0.25420  559322368  0.630041
# 2017-01-03     0.11290     0.25550     0.24640  559322369  0.622036
# 2017-01-03     0.11355     0.29300     0.26675  559328111  0.669891
# 2017-01-03     0.12240     0.29460     0.28950  559328112  0.619112
# ...                ...         ...         ...        ...       ...
# 2022-04-17     0.11270     0.20520     0.18950  307532496  0.563955
# 2022-04-17     0.13665     0.23835     0.27315  307535460  0.490798
# 2022-04-17     0.10625     0.22425     0.22230  307796387  0.566516
# 2022-04-17     0.12570     0.20880     0.25450  307097955  0.534379
# 2022-04-17     0.10180     0.19080     0.19740  901791744  0.635997
#
#                 area_m2                                             raster  \
# date
# 2017-01-03  4650.710032  S2A_MSIL1C_20170103T142022_N0204_R010_T20JLL_2...
# 2017-01-03  1502.000513  S2A_MSIL1C_20170103T142022_N0204_R010_T20JLL_2...
# 2017-01-03  2004.192528  S2A_MSIL1C_20170103T142022_N0204_R010_T20JLL_2...
# 2017-01-03  6940.507640  S2A_MSIL1C_20170103T142022_N0204_R010_T20JLL_2...
# 2017-01-03  4587.356048  S2A_MSIL1C_20170103T142022_N0204_R010_T20JLL_2...
# ...                 ...                                                ...
# 2022-04-17  3824.467794  S2A_MSIL1C_20220417T141741_N0400_R010_T20JLL_2...
# 2022-04-17  7184.535857  S2A_MSIL1C_20220417T141741_N0400_R010_T20JLL_2...
# 2022-04-17  1147.997645  S2A_MSIL1C_20220417T141741_N0400_R010_T20JLL_2...
# 2022-04-17  5185.690046  S2A_MSIL1C_20220417T141741_N0400_R010_T20JLL_2...
# 2022-04-17  9394.381202  S2A_MSIL1C_20220417T141741_N0400_R010_T20JLL_2...
#
#             clouds_on_raster      id      date1  ...  B11_median_imp_time  \
# date                                             ...
# 2017-01-03               0.0       1 2017-01-03  ...              0.18770
# 2017-01-03               0.0       2 2017-01-03  ...              0.25420
# 2017-01-03               0.0       3 2017-01-03  ...              0.24640
# 2017-01-03               0.0       4 2017-01-03  ...              0.26675
# 2017-01-03               0.0       5 2017-01-03  ...              0.28950
# ...                      ...     ...        ...  ...                  ...
# 2022-04-17               0.0  208928 2022-04-17  ...              0.18950
# 2022-04-17               0.0  208929 2022-04-17  ...              0.27315
# 2022-04-17               0.0  208930 2022-04-17  ...              0.22230
# 2022-04-17               0.0  208931 2022-04-17  ...              0.25450
# 2022-04-17               0.0  208932 2022-04-17  ...              0.19740
#
#             ndvi_max_imp_time  B02_median_imp_spline5  B06_median_imp_spline5  \
# date
# 2017-01-03           0.630881                 0.09650                 0.19910
# 2017-01-03           0.630041                 0.10660                 0.25960
# 2017-01-03           0.622036                 0.11290                 0.25550
# 2017-01-03           0.669891                 0.11355                 0.29300
# 2017-01-03           0.619112                 0.12240                 0.29460
# ...                       ...                     ...                     ...
# 2022-04-17           0.563955                 0.11270                 0.20520
# 2022-04-17           0.490798                 0.13665                 0.23835
# 2022-04-17           0.566516                 0.10625                 0.22425
# 2022-04-17           0.534379                 0.12570                 0.20880
# 2022-04-17           0.635997                 0.10180                 0.19080
#
#             B11_median_imp_spline5  ndvi_max_imp_spline5  out_B02  out_B06  \
# date
# 2017-01-03                 0.18770              0.630881        0        0
# 2017-01-03                 0.25420              0.630041        0        0
# 2017-01-03                 0.24640              0.622036        0        0
# 2017-01-03                 0.26675              0.669891        0        0
# 2017-01-03                 0.28950              0.619112        0        0
# ...                            ...                   ...      ...      ...
# 2022-04-17                 0.18950              0.563955        0        0
# 2022-04-17                 0.27315              0.490798        0        0
# 2022-04-17                 0.22230              0.566516        0        0
# 2022-04-17                 0.25450              0.534379        0        0
# 2022-04-17                 0.19740              0.635997        0        0
#
#             out_B11  out_ndvi_max
# date
# 2017-01-03        0             0
# 2017-01-03        0             0
# 2017-01-03        0             0
# 2017-01-03        0             0
# 2017-01-03        0             0
# ...             ...           ...
# 2022-04-17        0             0
# 2022-04-17        0             0
# 2022-04-17        0             0
# 2022-04-17        0             0
# 2022-04-17        0             0
#
# [208932 rows x 30 columns]

# %%
df_interest_extra2_=df_interest_extra2[['id','date1','B02_median_imp_spline5','B06_median_imp_spline5',
                                        'B11_median_imp_spline5','ndvi_max_imp_spline5',
                                        'out_B02','out_B06','out_B11','out_ndvi_max',
                                        'osm_id','ndvi_max','area_m2','raster','clouds_on_raster']]
df_interest_extra2_
#######
len(df_interest_extra2_)
df_interest_extra2_.describe()
# Out:
#                   id  B02_median_imp_spline5  B06_median_imp_spline5  \
# count  208932.000000           208932.000000           208932.000000
# mean   104466.500000                0.129448                0.218004
# std     60313.617559                0.031723                0.039565
# min         1.000000                0.061900                0.040500
# 25%     52233.750000                0.113100                0.198900
# 50%    104466.500000                0.126130                0.217450
# 75%    156699.250000                0.135068                0.235900
# max    208932.000000                0.689700                0.784500
#
#        B11_median_imp_spline5  ndvi_max_imp_spline5        out_B02  \
# count           208932.000000         208932.000000  208932.000000
# mean                 0.238815              0.502826       0.068544
# std                  0.051152              0.123984       0.252677
# min                  0.021300             -0.194614       0.000000
# 25%                  0.212402              0.437878       0.000000
# 50%                  0.238037              0.511299       0.000000
# 75%                  0.264000              0.589623       0.000000
# max                  0.806100              0.999486       1.000000
#
#              out_B06        out_B11   out_ndvi_max        osm_id  \
# count  208932.000000  208932.000000  208932.000000  2.089320e+05
# mean        0.065031       0.051074       0.049361  4.343631e+08
# std         0.246581       0.220149       0.216620  2.141069e+08
# min         0.000000       0.000000       0.000000  1.331006e+06
# 25%         0.000000       0.000000       0.000000  2.867065e+08
# 50%         0.000000       0.000000       0.000000  3.596742e+08
# 75%         0.000000       0.000000       0.000000  6.059767e+08
# max         1.000000       1.000000       1.000000  9.249657e+08
#
#             ndvi_max       area_m2  clouds_on_raster
# count  167260.000000  2.089320e+05     208932.000000
# mean        0.501846  1.249388e+04         19.473638
# std         0.137381  7.895730e+04         33.424013
# min        -0.194614  4.225951e+02          0.000000
# 25%         0.408413  2.066559e+03          0.000000
# 50%         0.516362  3.812182e+03          0.000000
# 75%         0.609126  6.644794e+03         25.009939
# max         0.999486  1.370630e+06        100.000000

# %%
# Se quitan aquellos registros donde se observa que para las tres bandas bajo análisis, los valores son outliers
df_interest_extra3_ = df_interest_extra2_[~((df_interest_extra2['out_B02']==1) & 
                                  (df_interest_extra2_['out_B06']==1) & 
                                  (df_interest_extra2_['out_B11']==1)& 
                                  (df_interest_extra2_['out_ndvi_max']==1))]
len(df_interest_extra3_)
df_interest_extra3_
# Out:
#                 id      date1  B02_median_imp_spline5  B06_median_imp_spline5  \
# date
# 2017-01-03       1 2017-01-03                 0.09650                 0.19910
# 2017-01-03       2 2017-01-03                 0.10660                 0.25960
# 2017-01-03       3 2017-01-03                 0.11290                 0.25550
# 2017-01-03       4 2017-01-03                 0.11355                 0.29300
# 2017-01-03       5 2017-01-03                 0.12240                 0.29460
# ...            ...        ...                     ...                     ...
# 2022-04-17  208928 2022-04-17                 0.11270                 0.20520
# 2022-04-17  208929 2022-04-17                 0.13665                 0.23835
# 2022-04-17  208930 2022-04-17                 0.10625                 0.22425
# 2022-04-17  208931 2022-04-17                 0.12570                 0.20880
# 2022-04-17  208932 2022-04-17                 0.10180                 0.19080
#
#             B11_median_imp_spline5  ndvi_max_imp_spline5  out_B02  out_B06  \
# date
# 2017-01-03                 0.18770              0.630881        0        0
# 2017-01-03                 0.25420              0.630041        0        0
# 2017-01-03                 0.24640              0.622036        0        0
# 2017-01-03                 0.26675              0.669891        0        0
# 2017-01-03                 0.28950              0.619112        0        0
# ...                            ...                   ...      ...      ...
# 2022-04-17                 0.18950              0.563955        0        0
# 2022-04-17                 0.27315              0.490798        0        0
# 2022-04-17                 0.22230              0.566516        0        0
# 2022-04-17                 0.25450              0.534379        0        0
# 2022-04-17                 0.19740              0.635997        0        0
#
#             out_B11  out_ndvi_max     osm_id  ndvi_max      area_m2  \
# date
# 2017-01-03        0             0  605976736  0.630881  4650.710032
# 2017-01-03        0             0  559322368  0.630041  1502.000513
# 2017-01-03        0             0  559322369  0.622036  2004.192528
# 2017-01-03        0             0  559328111  0.669891  6940.507640
# 2017-01-03        0             0  559328112  0.619112  4587.356048
# ...             ...           ...        ...       ...          ...
# 2022-04-17        0             0  307532496  0.563955  3824.467794
# 2022-04-17        0             0  307535460  0.490798  7184.535857
# 2022-04-17        0             0  307796387  0.566516  1147.997645
# 2022-04-17        0             0  307097955  0.534379  5185.690046
# 2022-04-17        0             0  901791744  0.635997  9394.381202
#
#                                                        raster  \
# date
# 2017-01-03  S2A_MSIL1C_20170103T142022_N0204_R010_T20JLL_2...
# 2017-01-03  S2A_MSIL1C_20170103T142022_N0204_R010_T20JLL_2...
# 2017-01-03  S2A_MSIL1C_20170103T142022_N0204_R010_T20JLL_2...
# 2017-01-03  S2A_MSIL1C_20170103T142022_N0204_R010_T20JLL_2...
# 2017-01-03  S2A_MSIL1C_20170103T142022_N0204_R010_T20JLL_2...
# ...                                                       ...
# 2022-04-17  S2A_MSIL1C_20220417T141741_N0400_R010_T20JLL_2...
# 2022-04-17  S2A_MSIL1C_20220417T141741_N0400_R010_T20JLL_2...
# 2022-04-17  S2A_MSIL1C_20220417T141741_N0400_R010_T20JLL_2...
# 2022-04-17  S2A_MSIL1C_20220417T141741_N0400_R010_T20JLL_2...
# 2022-04-17  S2A_MSIL1C_20220417T141741_N0400_R010_T20JLL_2...
#
#             clouds_on_raster
# date
# 2017-01-03               0.0
# 2017-01-03               0.0
# 2017-01-03               0.0
# 2017-01-03               0.0
# 2017-01-03               0.0
# ...                      ...
# 2022-04-17               0.0
# 2022-04-17               0.0
# 2022-04-17               0.0
# 2022-04-17               0.0
# 2022-04-17               0.0
#
# [206757 rows x 15 columns]

# %%
#La cantidad de observaciones que se quitan a partir del análisis del ruido es  208932-206757 =2175

# %%
import seaborn as sns
plt.figure(figsize=(60,10))
sns.histplot(data=df_interest_extra3_['clouds_on_raster'],binwidth=0.2)
# Out:
# <AxesSubplot:xlabel='clouds_on_raster', ylabel='Count'>

# %%
# Filtrar por nubosidad < 10%
df_interest_extra4=df_interest_extra3_[df_interest_extra3_['clouds_on_raster']<10]
len(df_interest_extra4)
# Out:
# 138545

# %%
df_interest_extra5=df_interest_extra3_[df_interest_extra3_['clouds_on_raster']<40]
len(df_interest_extra5)
df_interest_extra5.columns
# Out:
# Index(['id', 'date1', 'B02_median_imp_spline5', 'B06_median_imp_spline5',
#        'B11_median_imp_spline5', 'ndvi_max_imp_spline5', 'out_B02', 'out_B06',
#        'out_B11', 'out_ndvi_max', 'osm_id', 'ndvi_max', 'area_m2', 'raster',
#        'clouds_on_raster'],
#       dtype='object')

# %%
###Normalización de las variables bajo análisis en el rango 0,1
###################
from numpy import asarray
from sklearn.preprocessing import MinMaxScaler
# define min max scaler
scaler = MinMaxScaler()
# transform data
df_interest_extra4[['B02_median_imp_spline5_scl','B06_median_imp_spline5_scl',
                              'B11_median_imp_spline5_scl',
                              'ndvi_max_imp_spline5_scl',
                               'clouds_on_raster_scl']] = scaler.fit_transform(df_interest_extra4[['B02_median_imp_spline5',
                              'B06_median_imp_spline5',
                              'B11_median_imp_spline5',
                              'ndvi_max_imp_spline5',
                               'clouds_on_raster']])
df_interest_extra4
# Out:
# C:\Users\Varios\AppData\Local\Temp\ipykernel_14108\3563317896.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_interest_extra4[['B02_median_imp_spline5_scl','B06_median_imp_spline5_scl',
# C:\Users\Varios\anaconda3\lib\site-packages\pandas\core\indexing.py:1737: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
#                 id      date1  B02_median_imp_spline5  B06_median_imp_spline5  \
# date
# 2017-01-03       1 2017-01-03                 0.09650                 0.19910
# 2017-01-03       2 2017-01-03                 0.10660                 0.25960
# 2017-01-03       3 2017-01-03                 0.11290                 0.25550
# 2017-01-03       4 2017-01-03                 0.11355                 0.29300
# 2017-01-03       5 2017-01-03                 0.12240                 0.29460
# ...            ...        ...                     ...                     ...
# 2022-04-17  208928 2022-04-17                 0.11270                 0.20520
# 2022-04-17  208929 2022-04-17                 0.13665                 0.23835
# 2022-04-17  208930 2022-04-17                 0.10625                 0.22425
# 2022-04-17  208931 2022-04-17                 0.12570                 0.20880
# 2022-04-17  208932 2022-04-17                 0.10180                 0.19080
#
#             B11_median_imp_spline5  ndvi_max_imp_spline5  out_B02  out_B06  \
# date
# 2017-01-03                 0.18770              0.630881        0        0
# 2017-01-03                 0.25420              0.630041        0        0
# 2017-01-03                 0.24640              0.622036        0        0
# 2017-01-03                 0.26675              0.669891        0        0
# 2017-01-03                 0.28950              0.619112        0        0
# ...                            ...                   ...      ...      ...
# 2022-04-17                 0.18950              0.563955        0        0
# 2022-04-17                 0.27315              0.490798        0        0
# 2022-04-17                 0.22230              0.566516        0        0
# 2022-04-17                 0.25450              0.534379        0        0
# 2022-04-17                 0.19740              0.635997        0        0
#
#             out_B11  out_ndvi_max     osm_id  ndvi_max      area_m2  \
# date
# 2017-01-03        0             0  605976736  0.630881  4650.710032
# 2017-01-03        0             0  559322368  0.630041  1502.000513
# 2017-01-03        0             0  559322369  0.622036  2004.192528
# 2017-01-03        0             0  559328111  0.669891  6940.507640
# 2017-01-03        0             0  559328112  0.619112  4587.356048
# ...             ...           ...        ...       ...          ...
# 2022-04-17        0             0  307532496  0.563955  3824.467794
# 2022-04-17        0             0  307535460  0.490798  7184.535857
# 2022-04-17        0             0  307796387  0.566516  1147.997645
# 2022-04-17        0             0  307097955  0.534379  5185.690046
# 2022-04-17        0             0  901791744  0.635997  9394.381202
#
#                                                        raster  \
# date
# 2017-01-03  S2A_MSIL1C_20170103T142022_N0204_R010_T20JLL_2...
# 2017-01-03  S2A_MSIL1C_20170103T142022_N0204_R010_T20JLL_2...
# 2017-01-03  S2A_MSIL1C_20170103T142022_N0204_R010_T20JLL_2...
# 2017-01-03  S2A_MSIL1C_20170103T142022_N0204_R010_T20JLL_2...
# 2017-01-03  S2A_MSIL1C_20170103T142022_N0204_R010_T20JLL_2...
# ...                                                       ...
# 2022-04-17  S2A_MSIL1C_20220417T141741_N0400_R010_T20JLL_2...
# 2022-04-17  S2A_MSIL1C_20220417T141741_N0400_R010_T20JLL_2...
# 2022-04-17  S2A_MSIL1C_20220417T141741_N0400_R010_T20JLL_2...
# 2022-04-17  S2A_MSIL1C_20220417T141741_N0400_R010_T20JLL_2...
# 2022-04-17  S2A_MSIL1C_20220417T141741_N0400_R010_T20JLL_2...
#
#             clouds_on_raster  B02_median_imp_spline5_scl  \
# date
# 2017-01-03               0.0                    0.067132
# 2017-01-03               0.0                    0.095325
# 2017-01-03               0.0                    0.112910
# 2017-01-03               0.0                    0.114724
# 2017-01-03               0.0                    0.139428
# ...                      ...                         ...
# 2022-04-17               0.0                    0.112352
# 2022-04-17               0.0                    0.179204
# 2022-04-17               0.0                    0.094348
# 2022-04-17               0.0                    0.148639
# 2022-04-17               0.0                    0.081926
#
#             B06_median_imp_spline5_scl  B11_median_imp_spline5_scl  \
# date
# 2017-01-03                    0.343793                    0.288845
# 2017-01-03                    0.482364                    0.407341
# 2017-01-03                    0.472973                    0.393443
# 2017-01-03                    0.558864                    0.429704
# 2017-01-03                    0.562529                    0.470242
# ...                                ...                         ...
# 2022-04-17                    0.357765                    0.292053
# 2022-04-17                    0.433692                    0.441108
# 2022-04-17                    0.401397                    0.350499
# 2022-04-17                    0.366010                    0.407876
# 2022-04-17                    0.324782                    0.306130
#
#             ndvi_max_imp_spline5_scl  clouds_on_raster_scl
# date
# 2017-01-03                  0.622545                   0.0
# 2017-01-03                  0.621684                   0.0
# 2017-01-03                  0.613474                   0.0
# 2017-01-03                  0.662556                   0.0
# 2017-01-03                  0.610475                   0.0
# ...                              ...                   ...
# 2022-04-17                  0.553904                   0.0
# 2022-04-17                  0.478870                   0.0
# 2022-04-17                  0.556530                   0.0
# 2022-04-17                  0.523569                   0.0
# 2022-04-17                  0.627793                   0.0
#
# [138545 rows x 20 columns]

# %%
from pathlib import Path  
#filepath = Path('Resultado_tp1/DF.csv') 
filepath = Path('C:/Users/Varios/Desktop/Diplodatos/Resultado_receta_extra2.csv') 

filepath.parent.mkdir(parents=True, exist_ok=True)  
df_interest_extra4.to_csv(filepath)
